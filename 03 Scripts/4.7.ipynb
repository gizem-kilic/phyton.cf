# %%
import pandas as pd
import numpy as np
import os

# %%
# define function
def add_num(x,y) :
 sum = x+y
 return sum

# %%
add_num (9,11)
# Out:
# 20

# %%
x = sum(9, 11)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x = sum(9, 11)
#
# TypeError: 'int' object is not iterable

# %%
x = sum([9, 11])

# %%
x

# %%
# Load the DataFrame from the pickle file
ords_prods_merge = pd.read_pickle(r"C:\Users\gkgiz\Desktop\CF\Achievement 4\09 - 2024 Instacart Basket Analysis\02 Data\Prepared Data\ords_prods_merge.pkl")

# %%
df = ords_prods_merge[:1000000]

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
#creating a price range column

# %%
df['price_range'].value_counts(dropna = False)

# %%
df['prices'].max()

# %%
df['prices'].min()

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)

# %%
ords_prods_merge['order_dow'].value_counts(dropna = False)

# %%
result = []

for value in ords_prods_merge["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

#creating the busiest day column

# %% [markdown]
# result

# %%
ords_prods_merge['busiest day'] = result

# %%
ords_prods_merge
# Out:
#           Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0                  0   2539329        1    prior             1          2
# 1                  0   2539329        1    prior             1          2
# 2                  0   2539329        1    prior             1          2
# 3                  0   2539329        1    prior             1          2
# 4                  0   2539329        1    prior             1          2
# ...              ...       ...      ...      ...           ...        ...
# 32434207     3421081   2977660   206209    prior            13          1
# 32434208     3421081   2977660   206209    prior            13          1
# 32434209     3421081   2977660   206209    prior            13          1
# 32434210     3421081   2977660   206209    prior            13          1
# 32434211     3421081   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  new_order  product_id  \
# ...

# %%
ords_prods_merge['busiest day']. value_counts(dropna = False)
# Out:
# busiest day
# Regularly busy        14093045
# Busiest day            6209632
# Second busiest day     4500246
# Second slowest day     3844096
# Slowest day            3787193
# Name: count, dtype: int64

# %% [markdown]
# # Task 4.7

# %%
result2 = []

for value in ords_prods_merge["order_dow"]:
  if value == 0:
    result2.append("Busiest day")
  elif value == 6:
    result2.append("Second busiest day")
  elif value == 4:
    result2.append("Slowest day")
  elif value == 3:
    result2.append("Second slowest day")
  else:
    result2.append("Regularly busy")

#Step 2

# %%
ords_prods_merge['busiest days'] = result2

# %%
ords_prods_merge['busiest days'].value_counts(dropna = False)
# Out:
# busiest days
# Regularly busy        14093045
# Busiest day            6209632
# Second busiest day     4500246
# Second slowest day     3844096
# Slowest day            3787193
# Name: count, dtype: int64

# %% [markdown]
# The difference between the second busiest day and second slowest day is not immense, which means that the data in between doesnt vary so much from one day to another.

# %%
ords_prods_merge.describe()
# Out:
#          Unnamed: 0      order_id       user_id  order_number     order_dow  \
# count  3.243421e+07  3.243421e+07  3.243421e+07  3.243421e+07  3.243421e+07
# mean   1.709860e+06  1.710748e+06  1.029374e+05  1.714192e+01  2.738810e+00
# std    9.864638e+05  9.872996e+05  5.946649e+04  1.753489e+01  2.090047e+00
# min    0.000000e+00  2.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.556130e+05  8.559450e+05  5.142000e+04  5.000000e+00  1.000000e+00
# 50%    1.709152e+06  1.711049e+06  1.026125e+05  1.100000e+01  3.000000e+00
# 75%    2.565947e+06  2.565510e+06  1.543910e+05  2.400000e+01  5.000000e+00
# max    3.421081e+06  3.421083e+06  2.062090e+05  9.900000e+01  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.243421e+07            3.035613e+07  3.243421e+07
# mean        1.342500e+01            1.110416e+01  2.557778e+04
# std         4.246351e+00            8.778943e+00  1.409614e+04
# ...

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
# to disable the scientific notation

# %%
ords_prods_merge.describe()
# Out:
#        Unnamed: 0    order_id     user_id  order_number   order_dow  \
# count 32434212.00 32434212.00 32434212.00   32434212.00 32434212.00
# mean   1709860.21  1710747.96   102937.37         17.14        2.74
# std     986463.81   987299.60    59466.49         17.53        2.09
# min          0.00        2.00        1.00          1.00        0.00
# 25%     855613.00   855945.00    51420.00          5.00        1.00
# 50%    1709152.00  1711049.00   102612.50         11.00        3.00
# 75%    2565947.00  2565510.00   154391.00         24.00        5.00
# max    3421081.00  3421083.00   206209.00         99.00        6.00
#
#        order_hour_of_day  days_since_prior_order  product_id  \
# count        32434212.00             30356128.00 32434212.00
# mean               13.42                   11.10    25577.78
# std                 4.25                    8.78    14096.14
# min                 0.00                    0.00        1.00
# ...

# %% [markdown]
# Step 4: Orders are placed all day long, the majority of it being between 10:00am - 4:00pm. Therefore, "most orders" label would go to the orders placed during this period. "Average orders" go to all the orders placed between 00:00 and 10:00am, while fewest orders go to everything else.

# %%
result3 = []

for hour in ords_prods_merge['order_hour_of_day']:
    if 10 <= hour <= 16:
        result3.append("Most orders")
    elif 0 <= hour < 10:
        result3.append("Average orders")
    else:
        result3.append("Fewest orders")

# Add the result as a new column in the dataframe
ords_prods_merge['busiest_period_of_day'] = result3

# %%
ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Step 5: check the frequency for this new column.
# Out:
# busiest_period_of_day
# Most orders       18680601
# Fewest orders      7797484
# Average orders     5956127
# Name: count, dtype: int64

# %%
ords_prods_merge.to_pickle(r'C:\Users\gkgiz\Desktop\CF\Achievement 4\09 - 2024 Instacart Basket Analysis\02 Data\Prepared Data\'updated_orders.pkl')
